# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://results.eci.gov.in/PcResultGenJune2024/partywiseresult-S22.htm'
page = requests.get(url)
if page.status_code == 200:
    soup = BeautifulSoup(page.text, 'html.parser')
    print(soup)

else:
    print(f"Failed to retrieve the page. Status code: {page.status_code}")
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <!-- Required meta tags -->
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=7" http-equiv="X-UA-Compatible"/>
# <meta content="no-cache, no-store, must-revalidate" http-equiv="Cache-Control"/>
# <meta content="no-cache" http-equiv="Pragma"/>
# <meta content="0" http-equiv="Expires"/>
# <meta content="300" http-equiv="refresh"/>
# <!-- Bootstrap CSS -->
# <link href="css/bootstrap.min.css" rel="stylesheet"/>
# <link href="css/custom.css" rel="stylesheet"/>
# <link href="css/responsive.css" rel="stylesheet"/>
# <link href="css/font.css" rel="stylesheet"/>
# <link href="img/icons/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link crossorigin="" href="css/leaflet.css" integrity="sha256-kLaT2GOSpHechhsozzB+flnD+zUyjE2LlfWPgU04xyI=" rel="stylesheet">
# ...

# %%
table = soup.find('table', class_ ="table")
print(table)
# Out:
# <table class="table">
# <thead>
# <tr>
# <th style="text-align: left;">Party</th>
# <th style="text-align:right">Won</th>
# <th style="text-align:right">Leading</th>
# <th style="text-align:right">Total</th>
# </tr>
# </thead>
# <tbody>
# <tr class="tr">
# <td style="text-align:left">Dravida Munnetra Kazhagam - DMK</td>
# <td style="text-align:right">
# <a href="partywisewinresult-582S22.htm">22</a>
# </td>
# <td style="text-align:right">
#                                                                                         0
#                                                                                     </td>
# <td style="text-align:right">22</td>
# </tr>
# <tr class="tr">
# <td style="text-align:left">Indian National Congress - INC</td>
# <td style="text-align:right">
# <a href="partywisewinresult-742S22.htm">9</a>
# </td>
# <td style="text-align:right">
#                                                                                         0
# ...

# %%
elec_titles = table.find_all('thead')
headers = [header.text.split() for header in elec_titles]
headers = headers[0]
print(headers)
# Out:
# ['Party', 'Won', 'Leading', 'Total']

# %%
import pandas as pd
df = pd.DataFrame(columns = headers)

df
# Out:
# Empty DataFrame
# Columns: [Party, Won, Leading, Total]
# Index: []

# %%
column_data = table.find_all('tr')
print(column_data)
# Out:
# [<tr>
# <th style="text-align: left;">Party</th>
# <th style="text-align:right">Won</th>
# <th style="text-align:right">Leading</th>
# <th style="text-align:right">Total</th>
# </tr>, <tr class="tr">
# <td style="text-align:left">Dravida Munnetra Kazhagam - DMK</td>
# <td style="text-align:right">
# <a href="partywisewinresult-582S22.htm">22</a>
# </td>
# <td style="text-align:right">
#                                                                                         0
#                                                                                     </td>
# <td style="text-align:right">22</td>
# </tr>, <tr class="tr">
# <td style="text-align:left">Indian National Congress - INC</td>
# <td style="text-align:right">
# <a href="partywisewinresult-742S22.htm">9</a>
# </td>
# <td style="text-align:right">
#                                                                                         0
# ...

# %%
for row in column_data[1:-1]:
    row_data = row.find_all('td')
    individual_row_data = [data.text.strip() for data in row_data]

    length = len(df)
    df.loc[length] = individual_row_data

# %%
df
# Out:
#                                            Party Won Leading Total
# 0                Dravida Munnetra Kazhagam - DMK  22       0    22
# 1                 Indian National Congress - INC   9       0     9
# 2           Viduthalai Chiruthaigal Katchi - VCK   2       0     2
# 3                 Communist Party of India - CPI   2       0     2
# 4   Communist Party of India  (Marxist) - CPI(M)   2       0     2
# 5  Marumalarchi Dravida Munnetra Kazhagam - MDMK   1       0     1
# 6              Indian Union Muslim League - IUML   1       0     1

# %%
df.to_csv(r'C:\Projects Shata\LokSabha-WebScraping\TamilNadu_Results.csv',index=False)
